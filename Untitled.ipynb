# %%
data=open("train.txt",encoding='utf-8').readlines()

# %%
res=[i.strip().split(" ") for i in data]

# %%
tag=set()
for i in res:
    if len(i)==2:
        tag.add(i[1])
    else:
        print(i)
# Out:
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ['']
# ...

# %%
tag
# Out:
# {'B-NOUN_BOOKNAME', 'B-NOUN_OTHER', 'I-NOUN_BOOKNAME', 'I-NOUN_OTHER', 'O'}
